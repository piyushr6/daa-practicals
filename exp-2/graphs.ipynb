# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6))

# QuickSort subplot
# axes[0].plot(df['size'], df['quick bst'], label='Quick Best')
# axes[0].plot(df['size'], df['quick avg'], label='Quick Avg')
axes[0].plot(df['size'], df['quick worst'], label='Quick Worst')
axes[0].set_title('QuickSort Performance')
axes[0].set_xlabel('Size')
axes[0].set_ylabel('Time')
axes[0].legend()

# MergeSort subplot
axes[1].plot(df['size'], df['merge bst'], label='Merge Best')
axes[1].plot(df['size'], df['merge avg'], label='Merge Avg')
axes[1].plot(df['size'], df['merge worst'], label='Merge Worst')
axes[1].set_title('MergeSort Performance')
axes[1].set_xlabel('Size')
axes[1].set_ylabel('Time')
axes[1].legend()

plt.tight_layout()
plt.show()
